# %% [markdown]
# <a href="https://colab.research.google.com/github/vuvanvinh710/Construction-Safety/blob/main/detect_qu%E1%BA%A7n_%C3%A1o_b%E1%BA%A3o_h%E1%BB%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 49.9 MB/s eta 0:00:00
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="SPBFCnqF5YbmzWcq4yWd")
project = rf.workspace("ai-camp-safety-equipment-detection").project("ppe-detection-using-cv")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.9/207.9 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 31.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 41.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.13
#     Uninstalling idna-3.13:
#       Successfully uninstalled idna-3.13
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to PPE-Detection-Using-CV-1 in yolov8:: 100%|██████████| 2470/2470 [00:00<00:00, 5082.93it/s]
# ...

# %%
from ultralytics import YOLO

# 1. Khởi tạo mô hình YOLOv8 bản Nano (nhanh và nhẹ nhất)
model = YOLO('yolov8n.pt')

# 2. Bắt đầu huấn luyện
results = model.train(
    data='/content/PPE-Detection-Using-CV-1/data.yaml', # Thay bằng đường dẫn thực tế đến file data.yaml
    epochs=25,        # Số lượt học (25 là đủ để thấy kết quả nhanh trong hôm nay)
    imgsz=640,        # Kích thước ảnh đầu vào
    plots=True        # Vẽ biểu đồ kết quả để chúng ta cho vào CV
)
# Out:
# ...
# Ultralytics 8.4.47 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# Chạy dự đoán trên tập test
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/PPE-Detection-Using-CV-1/data.yaml
# Out:
# Ultralytics 8.4.47 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,007,013 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1169.2±739.2 MB/s, size: 41.8 KB)
# val: Scanning /content/PPE-Detection-Using-CV-1/valid/labels.cache... 243 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 243/243 32.9Mit/s 0.0s
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 2, len(boxes) = 860. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 16/16 2.0it/s 7.8s
#                    all        243        860      0.813      0.655      0.664        0.4
#                 Person        179        272      0.715      0.812      0.769      0.459
# ...
